# %% [markdown]
# # Tarefa 01
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %% [markdown]
# #### 1. Baixando dados de ativos
#     1. Baixe os dados de três ativos da sua escolha do Yahoo Finance, correspondente a um período de pelo menos 2 anos até a data mais recente.
#     2. Salve esses dados para que você possa utilizá-los na próxima tarefa.

# %%
import pandas as pd
from datetime import datetime


from pandas_datareader import data as pdr
import yfinance as yf
import plotly.express as px

# %%
# %%time
ativos = ['NVDA', 'ABEV3.SA', 'MGLU3.SA']
inicio = '2023-01-01'
fim = '2024-01-01'

dados_hist = yf.download(ativos, start=inicio, end=fim)

dados_hist.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
# CPU times: user 104 ms, sys: 288 µs, total: 104 ms
# Wall time: 117 ms
# Price           Close                             High                        \
# Ticker       ABEV3.SA   MGLU3.SA       NVDA   ABEV3.SA   MGLU3.SA       NVDA
# Date
# 2023-01-02  12.780699  24.224874        NaN  13.014877  24.879601        NaN
# 2023-01-03  12.762686  23.757212  14.304594  12.960836  25.814924  14.985100
# 2023-01-04  12.834741  23.850744  14.738279  13.032891  24.411940  14.842204
# 2023-01-05  12.870768  24.879601  14.254632  12.978850  25.347261  14.553414
# 2023-01-06  12.897788  25.814924  14.848200  12.933815  25.908457  14.999090
#
# Price             Low                             Open                        \
# Ticker       ABEV3.SA   MGLU3.SA       NVDA   ABEV3.SA   MGLU3.SA       NVDA
# Date
# 2023-01-02  12.627583  23.850744        NaN  12.969842  24.786068        NaN
# ...

# %%
dados_hist.to_csv('dados_historicos_acoes.csv')

# %% [markdown]
# #### 2. Observando a volatilidade dentro do dia
# 1. Calcule a amplitude de variação do valor do ativo dentro do dia. Essa amplitude você pode calcular com um comando simples de adicionar uma coluna no Pandas: (valor máximo - valor mínimo).
# 2. Monte um gráfico de linha mostrando a variação dessa amplitude ao longo do período coletado, por ativo.
# 3. Veja se consegue identificar que ativo apresentou maior volatilidade.

# %%
dados = dados_hist.stack().reset_index().copy()
dados
# Out:
# <ipython-input-89-698eafdda64f>:1: FutureWarning:
#
# The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
# Price       Date    Ticker      Close       High        Low       Open  \
# 0     2023-01-02  ABEV3.SA  12.780699  13.014877  12.627583  12.969842
# 1     2023-01-02  MGLU3.SA  24.224874  24.879601  23.850744  24.786068
# 2     2023-01-03  ABEV3.SA  12.762686  12.960836  12.708644  12.753679
# 3     2023-01-03  MGLU3.SA  23.757212  25.814924  23.383083  24.318405
# 4     2023-01-03      NVDA  14.304594  14.985100  14.085753  14.840205
# ..           ...       ...        ...        ...        ...        ...
# 741   2023-12-27      NVDA  49.402988  49.665914  49.071082  49.496964
# 742   2023-12-28  ABEV3.SA  13.012774  13.126506  13.012774  13.079117
# ...

# %%
dados['valor'] = dados['High']-dados['Low']
dados
# Out:
# Price       Date    Ticker      Close       High        Low       Open  \
# 0     2023-01-02  ABEV3.SA  12.780699  13.014877  12.627583  12.969842
# 1     2023-01-02  MGLU3.SA  24.224874  24.879601  23.850744  24.786068
# 2     2023-01-03  ABEV3.SA  12.762686  12.960836  12.708644  12.753679
# 3     2023-01-03  MGLU3.SA  23.757212  25.814924  23.383083  24.318405
# 4     2023-01-03      NVDA  14.304594  14.985100  14.085753  14.840205
# ..           ...       ...        ...        ...        ...        ...
# 741   2023-12-27      NVDA  49.402988  49.665914  49.071082  49.496964
# 742   2023-12-28  ABEV3.SA  13.012774  13.126506  13.012774  13.079117
# 743   2023-12-28  MGLU3.SA  20.202984  20.857710  20.109451  20.670645
# 744   2023-12-28      NVDA  49.507965  49.869862  49.397996  49.628933
# 745   2023-12-29      NVDA  49.507965  49.982833  48.737184  49.798883
#
# Price       Volume  Amplitude     valor
# 0       14995900.0   0.387293  0.387293
# ...

# %%
fig = px.line(dados, x='Date', y='valor', color='Ticker', template='plotly_dark')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
mais_volatil = dados.sort_values(by=['Amplitude'],ascending=False).iloc[0]
mais_volatil
# Out:
# Price
# Date         2023-05-16 00:00:00
# Ticker                  MGLU3.SA
# Close                  31.613928
# High                   38.348255
# Low                     31.33333
# Open                   37.506466
# Volume                37179966.0
# Amplitude               7.014925
# valor                   7.014925
# Name: 275, dtype: object

# %% [markdown]
# O ativo apresentou maior volatilidade foi o MGLU3.SA
