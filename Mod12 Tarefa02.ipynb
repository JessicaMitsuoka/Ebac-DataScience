# %% [markdown]
# # Regressão 01 - tarefa 02 - transformações em X e Y

# %% [markdown]
# ### 1. Melhorando o ajuste no percentual de gorjetas
#
# a. Vamos partir do modelo feito na última tarefa, o que relaciona ```tip_pct``` e ```net_bill```. Carregue a base, os pacotes e reproduza este modelo aqui.

# %%
import pandas as pd
import seaborn as sns
from seaborn import load_dataset

import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
tips = sns.load_dataset('tips')
tips['tip_pct'] = (tips['tip']/ (tips['total_bill'])) * 100
tips['net_bill'] = tips['total_bill'] - tips['tip']
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size    tip_pct  net_bill
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673     15.98
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159      8.68
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734     17.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041     20.37
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765     20.98

# %%
x = tips['net_bill']
y = tips['tip_pct']

reg = smf.ols('tip_pct ~ net_bill', data = tips).fit()
tips['tip_pct_predito'] = reg.predict(tips['net_bill'])

# %%
plt.scatter(tips['net_bill'], tips['tip_pct'], label = 'Real')
plt.plot(tips['net_bill'], tips['tip_pct_predito'], label = 'Predito', color = 'red')
plt.xlabel('Variavel Independente')
plt.ylabel('tip_pct')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
tips['res'] = reg.resid

sns.scatterplot(x= 'net_bill', y= 'res', data= tips, alpha= .75)
plt.axhline(y= 0, color= 'r', linestyle= '--')

# %%
sns.regplot(x= 'net_bill', y= 'tip_pct', data= tips)
plt.plot(tips['net_bill'], reg.fittedvalues, 'r,--')

# %% [markdown]
# ### 2. ajuste o modelo de ```tip_pct``` em função do logaritmo de ```net_bill```.

# %%
reg= smf.ols('tip_pct ~ np.log(net_bill)', data= tips).fit()
print(reg.summary())
tips['res']= reg.resid

sns.scatterplot(x= 'net_bill', y= 'res', data= tips, alpha= .75)
plt.axhline(y= 0, color= 'r', linestyle= '--')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                tip_pct   R-squared:                       0.289
# Model:                            OLS   Adj. R-squared:                  0.286
# Method:                 Least Squares   F-statistic:                     98.21
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):           1.19e-19
# Time:                        08:09:47   Log-Likelihood:                -745.67
# No. Observations:                 244   AIC:                             1495.
# Df Residuals:                     242   BIC:                             1502.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           34.6800      1.906     18.198      0.000      30.926      38.434
# np.log(net_bill)    -6.8596      0.692     -9.910      0.000      -8.223      -5.496
# ==============================================================================
# Omnibus:                      169.023   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2946.559
# Skew:                           2.432   Prob(JB):                         0.00
# Kurtosis:                      19.314   Cond. No.                         17.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ###  3. ajuste o modelo de ```tip_pct``` em função de um polinômio de segundo grau em ```net_bill```.

# %%
reg= smf.ols('tip_pct ~ np.power(net_bill,2)', data= tips).fit()
print(reg.summary())
tips['res']= reg.resid

sns.scatterplot(x= 'net_bill', y= 'res', data= tips, alpha= .75)
plt.axhline(y= 0, color= 'r', linestyle= '--')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                tip_pct   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     37.33
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):           3.96e-09
# Time:                        08:09:51   Log-Likelihood:                -769.73
# No. Observations:                 244   AIC:                             1543.
# Df Residuals:                     242   BIC:                             1550.
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                18.2625      0.510     35.778      0.000      17.257      19.268
# np.power(net_bill, 2)    -0.0063      0.001     -6.110      0.000      -0.008      -0.004
# ==============================================================================
# Omnibus:                      238.426   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9742.906
# Skew:                           3.698   Prob(JB):                         0.00
# Kurtosis:                      33.060   Cond. No.                         692.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.regplot(x= 'net_bill', y= 'tip_pct', data= tips)
plt.plot(tips['net_bill'], reg.fittedvalues, 'r,--')

# %% [markdown]
# ###  4. ajuste um modelo no log do ```tip_pct``` em função de ```net_bill```. Calcule o $R^2$ também em ```tip_pct```

# %%
reg= smf.ols('np.log(tip_pct) ~ net_bill', data= tips).fit()
print(reg.summary())
tips['res']= reg.resid

sns.scatterplot(x= 'net_bill', y= 'res', data= tips, alpha= .75)
plt.axhline(y= 0, color= 'r', linestyle= '--')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        np.log(tip_pct)   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.241
# Method:                 Least Squares   F-statistic:                     77.95
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):           2.18e-16
# Time:                        08:10:00   Log-Likelihood:                -55.678
# No. Observations:                 244   AIC:                             115.4
# Df Residuals:                     242   BIC:                             122.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.0787      0.045     67.886      0.000       2.989       3.168
# net_bill      -0.0215      0.002     -8.829      0.000      -0.026      -0.017
# ==============================================================================
# Omnibus:                       11.472   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               23.632
# Skew:                          -0.141   Prob(JB):                     7.39e-06
# Kurtosis:                       4.498   Cond. No.                         43.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.regplot(x= 'net_bill', y= 'tip_pct', data= tips)
plt.plot(tips['net_bill'], reg.fittedvalues, 'r,--')

# %% [markdown]
# ###  5. ajuste um modelo no log do ```tip_pct``` em função do log de ```net_bill```. Calcule o $R^2$ também em ```tip_pct```.

# %%
reg= smf.ols('np.log(tip_pct) ~ np.log(net_bill)', data= tips).fit()
print(reg.summary())
tips['res']= reg.resid

sns.scatterplot(x= 'net_bill', y= 'res', data= tips, alpha= .75)
plt.axhline(y= 0, color= 'r', linestyle= '--')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        np.log(tip_pct)   R-squared:                       0.280
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     94.10
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):           5.26e-19
# Time:                        08:10:09   Log-Likelihood:                -49.670
# No. Observations:                 244   AIC:                             103.3
# Df Residuals:                     242   BIC:                             110.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            3.7679      0.110     34.266      0.000       3.551       3.985
# np.log(net_bill)    -0.3874      0.040     -9.700      0.000      -0.466      -0.309
# ==============================================================================
# Omnibus:                       10.347   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               11.432
# Skew:                          -0.397   Prob(JB):                      0.00329
# Kurtosis:                       3.702   Cond. No.                         17.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
tips['pred_y']= np.exp(reg.fittedvalues)
tips[['pred_y', 'tip_pct']].corr().iloc[0,1]**2

sns.regplot(x= 'net_bill', y= 'tip_pct', data= tips)
plt.plot(tips['net_bill'], tips['pred_y'], 'r,--')
print(reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        np.log(tip_pct)   R-squared:                       0.280
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     94.10
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):           5.26e-19
# Time:                        08:10:13   Log-Likelihood:                -49.670
# No. Observations:                 244   AIC:                             103.3
# Df Residuals:                     242   BIC:                             110.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            3.7679      0.110     34.266      0.000       3.551       3.985
# np.log(net_bill)    -0.3874      0.040     -9.700      0.000      -0.466      -0.309
# ==============================================================================
# Omnibus:                       10.347   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               11.432
# Skew:                          -0.397   Prob(JB):                      0.00329
# Kurtosis:                       3.702   Cond. No.                         17.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ###  6. qual modelo resultou no melhor ajuste?

# %% [markdown]
# O resultado que apresentou melhor resultado foi o com o net_bill na base log, tendo um R2 maior que o anterior.
